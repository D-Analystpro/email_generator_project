# %%
# %pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.8-cp39-abi3-win_amd64.whl (23.4 MB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.11.8)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.2.6)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting rich>=10.11.0
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Collecting build>=1.0.3
#   Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.28.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.26.0)
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.0.3)
# Collecting typer>=0.9.0
#   Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.14.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.46.0)
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.80.0-cp310-cp310-win_amd64.whl (4.9 MB)
# Collecting pypika>=0.48.9
#   Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.2.1-cp310-cp310-win_amd64.whl (41 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.23.2-cp310-cp310-win_amd64.whl (13.5 MB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.13.3)
# Collecting pybase64>=1.4.1
#   Downloading pybase64-1.4.3-cp310-cp310-win_amd64.whl (35 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.4.1-py3-none-any.whl (14 kB)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in c:\users\bhans\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: packaging>=24.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: httpcore==1.* in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: certifi in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.8.3)
# Requirement already satisfied: anyio in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: h11>=0.16 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: requests in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Collecting flatbuffers
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: protobuf in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.34.1)
# Collecting importlib-metadata>=4.6
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Collecting googleapis-common-protos~=1.57
#   Downloading googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (18 kB)
# Collecting opentelemetry-proto==1.41.1
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
# Collecting protobuf
#   Downloading protobuf-6.33.6-cp310-abi3-win_amd64.whl (437 kB)
# Collecting opentelemetry-semantic-conventions==0.62b1
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.0->chromadb) (2.46.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhans\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting huggingface-hub<2.0,>=0.16.4
#   Downloading huggingface_hub-1.13.0-py3-none-any.whl (660 kB)
# Collecting hf-xet<2.0.0,>=1.4.3
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: click>=8.2.1 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.3)
# Collecting watchfiles>=0.20
#   Downloading watchfiles-1.1.1-cp310-cp310-win_amd64.whl (287 kB)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bhans\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bhans\appdata\local\programs\python\python310\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.3)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: zipp, mdurl, markdown-it-py, importlib-metadata, shellingham, rich, pyreadline3, protobuf, opentelemetry-api, annotated-doc, typer, tqdm, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, mpmath, humanfriendly, hf-xet, fsspec, websocket-client, watchfiles, tomli, sympy, requests-oauthlib, pyproject-hooks, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-common, huggingface-hub, grpcio, googleapis-common-protos, flatbuffers, durationpy, coloredlogs, tokenizers, pypika, pybase64, overrides, opentelemetry-exporter-otlp-proto-grpc, onnxruntime, mmh3, kubernetes, importlib-resources, build, bcrypt, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 7.34.1
#     Uninstalling protobuf-7.34.1:
#       Successfully uninstalled protobuf-7.34.1
# Successfully installed annotated-doc-0.0.4 bcrypt-5.0.0 build-1.5.0 chromadb-1.5.8 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.12.19 fsspec-2026.4.0 googleapis-common-protos-1.74.0 grpcio-1.80.0 hf-xet-1.4.3 huggingface-hub-1.13.0 humanfriendly-10.0 importlib-metadata-8.7.1 importlib-resources-7.1.0 kubernetes-35.0.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.1 mpmath-1.3.0 oauthlib-3.3.1 onnxruntime-1.23.2 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 overrides-7.7.0 protobuf-6.33.6 pybase64-1.4.3 pypika-0.51.1 pyproject-hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rich-15.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.23.1 tomli-2.4.1 tqdm-4.67.3 typer-0.25.1 watchfiles-1.1.1 websocket-client-1.9.0 zipp-3.23.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script humanfriendly.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchfiles.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script coloredlogs.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybase64.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script onnxruntime_test.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyproject-build.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script chroma.exe is installed in 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 26.1 is available.
# You should consider upgrading via the 'c:\Users\bhans\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import chromadb
client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids = ['id1', 'id2']
)
# Out:
# C:\Users\bhans\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [01:33<00:00, 892kiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=['Query is about big apple'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.6312181949615479, 1.867558479309082]]}

# %%
collection.delete(ids=all_docs['ids'])
collection.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=["id3", "id4"],
    metadatas=[
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/New_Delhi"}
    ]
)

# %%
results = collection.query(
    query_texts=["Query is about Chhole Bhature"],
    n_results=2
)
results
# Out:
# {'ids': [['id4', 'id3']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/New_Delhi'},
#    {'url': 'https://en.wikipedia.org/wiki/New_York_City'}]],
#  'distances': [[1.5588479042053223, 1.8114913702011108]]}
